# %%
# !pip install wordcloud``
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/d0/67/ebbc7e0c6da1753d7c30c2ca47c6bd11dbf2259cfa9c98151f4ab3d8b950/wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in d:\python\anaconda3\envs\acl\lib\site-packages (from wordcloud) (1.24.1)
# Requirement already satisfied: pillow in d:\python\anaconda3\envs\acl\lib\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in d:\python\anaconda3\envs\acl\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\python\anaconda3\envs\acl\lib\site-packages (from matplotlib->wordcloud) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in d:\python\anaconda3\envs\acl\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.16.2)
# Requirement already satisfied: six>=1.5 in d:\python\anaconda3\envs\acl\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.6 kB 119.1 kB/s eta 0:00:03
#    ----- --------------------------------- 41.0/300.6 kB 131.3 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/300.6 kB 131.3 kB/s eta 0:00:02
#    ------- ------------------------------- 61.4/300.6 kB 164.1 kB/s eta 0:00:02
#    ----------- --------------------------- 92.2/300.6 kB 209.5 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/300.6 kB 242.7 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/300.6 kB 240.2 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/300.6 kB 266.2 kB/s eta 0:00:01
#    ------------------------ ------------- 194.6/300.6 kB 318.9 kB/s eta 0:00:01
#    ---------------------------- --------- 225.3/300.6 kB 344.1 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/300.6 kB 374.6 kB/s eta 0:00:01
#    ---------------------------------- --- 276.5/300.6 kB 378.7 kB/s eta 0:00:01
#    -------------------------------------- 300.6/300.6 kB 395.6 kB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
file = 'D:/CODE/lin_graph/train_sent_dense'
with open(file, 'r') as f:
    data = f.readlines()
    data = [line.strip() for line in data]
    data = ' '.join(data)

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=("Python Python Python Matplotlib")
text=data

# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0, background_color='white').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=data

# Create the wordcloud object
wordcloud = WordCloud(
    width=480, height=480,
    max_font_size=100, min_font_size=10,
    background_color='white'
).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
